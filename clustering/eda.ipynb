# %%
import pandas as pd

# %%
# to look at all columns in a dataframe
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/clusters.csv')

# %%
cluster_modes = df.drop('CASEID',axis=1).groupby('Cluster').apply(lambda x: x.mode().iloc[0])
cluster_modes
# Out:
# 0       RELIG_SERVICES_12month RELIG_IMPORTANT RELIG_influ_decision
# Cluster
# 0                            0  Strongly Agree       Strongly Agree  \
# 1                            0           Agree                Agree
# 2                            0           Agree                Agree
#
# 0         friend_SHARE_REL Tabacco_Flag Alcohol_Flag Marijunana_Flag
# Cluster
# 0        Strongly Disagree          Yes          Yes              No  \
# 1                 Disagree          Yes          Yes             Yes
# 2                 Disagree           No          Yes              No
#
# 0       Marijuana_Only_Flag Cocaine_Flag Crack_Flag Herion_Flag
# Cluster
# 0                        No           No         No          No  \
# 1                        No           No         No          No
# 2                        No           No         No          No
#
# 0       Hallcinogens_Flag Inhalants_Flag Painkiller_Flag Tranquilizer_Flag
# Cluster
# ...
